# %%
import IPython

# %%
IPython.display.Audio("samples/Bryan_-_The_Ideal_Republic.ogg")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
